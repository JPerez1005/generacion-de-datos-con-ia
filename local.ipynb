# %%
pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in c:\users\perez\appdata\local\programs\python\python313\lib\site-packages (0.27.0)
# Requirement already satisfied: filelock in c:\users\perez\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\perez\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\perez\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\perez\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in c:\users\perez\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\perez\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\perez\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: colorama in c:\users\perez\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\perez\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface_hub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\perez\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\perez\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface_hub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\perez\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface_hub) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Modelo Local

# %%
pip install transformers[torch]

# %%
from transformers import pipeline

# Cargar el modelo localmente
sentiment_model = pipeline("sentiment-analysis")

# Análisis de un texto
result = sentiment_model("i'm very sick")
print(result)
